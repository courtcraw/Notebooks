# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (12,8)
plt.rcParams['font.size'] = 20
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 17
plt.rcParams['axes.labelsize'] = 30

# %%
from astropy.io import fits

# %%
spectrum = fits.open('../A0620-00/00Dec24-1n.fits')

# %%
spectrum.info()
# Out:
# Filename: ../A0620-00/00Dec24-1n.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     107   (546,)   float32

# %%
spectrum[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    1 / Number of axes
# NAXIS1  =                  546 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '12:14:21 (05/11/2004)' / Time of last modification
# OBJECT  = 'A0620-00'           / Name of the object observed
# CRVAL1  =  6.2500000000000E+03 / Wavelength
# CDELT1  =      1.1093247588424 /
# CRPIX1  =         1.000000E+00 /
# CTYPE1  = 'LINEAR  '           /
# DATE    = '2004-11-05T00:14:21' /
# IRAF-MAX=  6.5012550000000E+03 / DATA MAX
# IRAF-MIN= -5.5536380000000E+01 / DATA MIN
# RA      =  6.3782230000000E+00 / Initial RA 06 22 41.6
# DEC     =                    0 / Initial Dec -0 20 32
# EQUINOX = 'B2000.0           ' /
# SIDEREAL=                    0 / Local sidereal time 03:07:03.0
# MJD     =  5.1902456732000E+04 / Modified Julian Date
# OBSERVAT= 'SSO               ' /
# TELESCOP= '2.3METRE          ' /
# COMMENT     = 'Telescope object name'/ Not
# COMMENT     = 'Side of pier'       / Not a
# COMMENT     = ''                   /
# COMMENT     = 'FILTER'             / Not a
# COMMENT     = 'FITSKW1'            / Not a
# COMMENT     = 'FITSKW2'            / Not a
# COMMENT     = 'FITSKW3'            / Not a
# COMMENT     = 'FITSKW4'            / Not a
# COMMENT     = 'GAIN'               / Not a
# LAT-OBS = -3.1273360000000E+01 / Degrees
# LONG-OBS=  1.4906120000000E+02 / Degrees east of Greenwich
# ALT-OBS =                 1149 / Metres above mean sea level
# AIRMASS =  1.7661920000000E+00 /
# UT      = '10:57:45.90       ' / UT read from telescope
# POSANG  =                    0 /
# UTDATE  = '24-DEC-00         ' / UT date read from telescope
# DATE-OBS= '24/12/00          ' / UT date read from telescope
# OBSID   = '5                 ' / Observation identification
# IMAGETYP= 'OBJECT            ' / Observation type
# EXPREQ  =                 1800 / Requested exposure time (sec)
# EXPTIME =                 1800 / Exposure time (sec)
# DARKTIME=                 1800 / Dark time (sec)
# CAMERA  = 'MSSSO9            ' / Camera name
# DEWAR   = 'D9                ' / Dewar name
# DETECTOR= 'MSSSO9            ' / Detector Name
# DETSIZE = '[1:1798,1:532]    ' / Detector size
# NCCDS   =                    1 / Number of CCDs
# CONTROLR= 'AM CCD9           ' / Controller Name
# CCDNAME = 'CCD9              ' / CCD identification
# CCDSIZE = '[1:1798,1:532]    ' / CCD size
# CCDNAMPS=                    1 / Number of amplifiers used
# AMPNAME = 'A                 ' / Amplifier identification
# AMPSIZE = '[1:1798,1:532]    ' / Amplifier size
# CCDSEC  = '[26:1500,201:400] ' / Region of CCD read
# CCDSUM  = '1 1               ' / CCD pixel summing
# AMPSEC  = '[1:1798,1:532]    ' / Amplifier section
# DETSEC  = '[1:1798,1:532]    ' / Detector section
# DATAACQ = 'CICADA RELEASE 2.0.10' /
# WCSDIM  =                    1 /3 /
# LTM1_1  =                    1 /
# WAT0_001= 'system=equispec'    /
# WAT1_001= 'wtype=linear label=Wavelength units=angstroms units_display=Angstrom'
# CCDPROC = 'JUL 17  9:55 CCD PROCESSING DONE' /
# TRIM    = 'JUL 17  9:40 TRIM DATA SECTION IS [26:15' /
# OVERSCAN= 'JUL 17  9:40 OVERSCAN SECTION IS [1777:1' /
# ZEROCOR = 'JUL 17  9:40 ZERO LEVEL CORRECTION IMAGE' /
# FLATCOR = 'JUL 17  9:55 FLAT FIELD IMAGE IS NFLAT_R' /
# HISTORY     New copy of s005r.imh
# HISTORY     New copy of s005r.imh
# HISTORY     New copy of s005r.imh
# HISTORY   'KPNO-IRAF         ' /
# HISTORY   '2001-07-16T23:12:54' /
# HISTORY   New copy of s005rc
# HISTORY   New copy of s005rc.ms
# HISTORY   New copy of ds005rc.ms
# APNUM1  = '1 0 1.00 1.00 1.00 1.00' /
# CD1_1   =  1.1093247588424E+00 /
# OLDRA   =  1.6698150000000E+00 /
# OLDDEC  =                    0 /
# EPOCH   =                 1950 /
# JD      =  2.4519029671979E+06 /
# HJD     =  2.4519029723845E+06 /
# LJD     =              2451903 /
# DC-FLAG =                    0 /0 /
# DCLOG1  = 'REFSPEC1 = ARC007R' /
# BANDID1 = 'SPECTRUM - BACKGROUND FIT, WEIGHTS VARIA' /
# BANDID2 = 'RAW - BACKGROUND FIT, WEIGHTS NONE, CLEA' /
# BANDID3 = 'BACKGROUND - BACKGROUND FIT' /
# BANDID4 = 'SIGMA - BACKGROUND FIT, WEIGHTS VARIANCE' /
# WAT1_002= 's       '

# %%
print(spectrum[0].header['JD'])
# Out:
# 2451902.9671979

# %%
spectrum[0].data
# Out:
# array([0.8867787 , 0.9300327 , 1.005985  , 1.0021417 , 0.918191  ,
#        0.94991165, 1.0235387 , 1.004308  , 1.0262696 , 0.9959083 ,
#        1.0179235 , 1.1280973 , 1.1388981 , 1.0792161 , 1.0565264 ,
#        1.0822942 , 1.1208165 , 1.1209873 , 1.1236501 , 0.9749278 ,
#        0.9022368 , 0.99861854, 0.9844407 , 1.0459235 , 1.063029  ,
#        1.0453962 , 0.955646  , 0.93459684, 1.0163819 , 1.0281266 ,
#        0.9524303 , 1.0091199 , 1.0289568 , 1.0269947 , 1.0979457 ,
#        1.0599648 , 0.98879826, 1.0361279 , 1.081925  , 1.006528  ,
#        0.9098615 , 1.0100538 , 1.0539061 , 0.94156045, 1.0152268 ,
#        1.0463032 , 1.0006491 , 1.0489423 , 1.0428746 , 0.9870344 ,
#        0.98812455, 0.9902691 , 0.92921954, 0.92946625, 0.97509843,
#        0.99446905, 0.9612158 , 0.8675249 , 0.87448305, 1.0137352 ,
#        1.0575976 , 0.94645935, 1.0097306 , 1.0142381 , 0.90413344,
#        0.8169959 , 0.8822155 , 1.0047275 , 1.0953759 , 1.0790524 ,
#        1.0478247 , 1.0334502 , 1.0552144 , 0.954764  , 0.93375367,
#        0.97852314, 1.0947028 , 1.0331957 , 0.91033477, 0.9801672 ,
#        1.0931026 , 0.986944  , 0.94541246, 1.0983775 , 1.0718486 ,
#        0.987292  , 0.9981132 , 1.0315008 , 1.0540001 , 0.9709504 ,
#        0.91872394, 0.96358883, 1.0294955 , 0.9773375 , 0.95061094,
#        0.9533042 , 1.034598  , 1.0070834 , 0.9690573 , 0.9528169 ,
#        1.0211493 , 1.0337601 , 1.0957848 , 1.0412107 , 1.008861  ,
#        1.0503896 , 0.97668403, 1.042005  , 0.93808645, 0.9265899 ,
#        0.91528636, 0.95561844, 1.019512  , 1.0404679 , 1.0015802 ,
#        0.99534273, 1.0664432 , 1.0190742 , 0.9322008 , 0.97156554,
#        0.9355868 , 1.0382668 , 0.9925425 , 0.9308538 , 0.97789276,
#        1.0465187 , 0.9902653 , 1.0210327 , 1.0172648 , 0.92093116,
#        0.98959863, 1.0180668 , 0.975721  , 1.0685744 , 1.0027317 ,
#        0.9649698 , 1.003265  , 0.99128765, 0.99358493, 1.0749338 ,
#        1.0252676 , 1.0349534 , 1.0317245 , 0.9922588 , 1.0209439 ,
#        1.0511647 , 0.9865205 , 0.9996907 , 0.99014413, 1.001897  ,
#        0.97747356, 1.0122373 , 0.995218  , 0.9739952 , 0.9653003 ,
#        1.0430661 , 1.0934056 , 1.0067464 , 0.93459916, 0.9829497 ,
#        1.0169455 , 0.9859429 , 0.9799487 , 0.96854967, 0.996205  ,
#        1.0202123 , 0.9415367 , 0.9497814 , 1.0143917 , 1.0429987 ,
#        1.0449297 , 1.0416028 , 1.0185791 , 0.9969024 , 1.0826333 ,
#        1.054437  , 0.89059275, 0.8646044 , 0.98014027, 1.0239362 ,
#        0.9792004 , 1.0539218 , 1.1433237 , 1.0853957 , 0.9912419 ,
#        0.9127475 , 1.0048339 , 1.0720258 , 0.9605988 , 0.95502007,
#        0.97175   , 0.9529324 , 0.9896597 , 1.0176332 , 1.0514929 ,
#        1.0395253 ], dtype=float32)

# %%
plt.figure(figsize=(12,6))
plt.plot(spectrum[0].data)
plt.xlabel('wavelength (pixel)')
plt.ylabel('flux (arb. units)')
plt.show()
