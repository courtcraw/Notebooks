# %%
import read_mist_models
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
isocmd = read_mist_models.ISOCMD('../MIST_iso_6368865a8c0c6.iso.cmd')
# isocmd = read_mist_models.ISOCMD('../MIST_iso_6369c12359ffa.iso.cmd')
# Out:
# Reading in: ../MIST_iso_6368865a8c0c6.iso.cmd

# %%
print('version: ', isocmd.version)
print('photometric system: ', isocmd.photo_sys)
print('abundances: ', isocmd.abun)
print('rotation: ', isocmd.rot)
print('ages: ', [round(x,2) for x in isocmd.ages])
print('number of ages: ', isocmd.num_ages)
print('available columns: ', isocmd.hdr_list)
print('Av extinction: ', isocmd.Av_extinction)
# Out:
# version:  {'MIST': '1.2', 'MESA': '7503'}
# photometric system:  UBV(RI)c, 2MASS, Kepler, Hipparcos, Gaia (Vega)
# abundances:  {'Yinit': 0.2703, 'Zinit': 0.0142, '[Fe/H]': 0.0, '[a/Fe]': 0.0}
# rotation:  0.0
# ages:  [8.04]
# number of ages:  1
# available columns:  ['EEP', 'log10_isochrone_age_yr', 'initial_mass', 'star_mass', 'log_Teff', 'log_g', 'log_L', '[Fe/H]_init', '[Fe/H]', 'Bessell_U', 'Bessell_B', 'Bessell_V', 'Bessell_R', 'Bessell_I', '2MASS_J', '2MASS_H', '2MASS_Ks', 'Kepler_Kp', 'Kepler_D51', 'Hipparcos_Hp', 'Tycho_B', 'Tycho_V', 'Gaia_G_DR2Rev', 'Gaia_BP_DR2Rev', 'Gaia_RP_DR2Rev', 'Gaia_G_MAW', 'Gaia_BP_MAWb', 'Gaia_BP_MAWf', 'Gaia_RP_MAW', 'TESS', 'Gaia_G_EDR3', 'Gaia_BP_EDR3', 'Gaia_RP_EDR3', 'phase']
# Av extinction:  0.0

# %%
# M_G = isocmd.isocmds[0]['Gaia_G_EDR3'] - 5*np.log10(135) + 5
# print(M_G)
# print(isocmd.isocmds[0]['log10_isochrone_age_yr'])

# plt.plot(isocmd.isocmds[0]['Gaia_BP_EDR3']-isocmd.isocmds[0]['Gaia_RP_EDR3'],M_G,
#         marker='.',markersize=1, markerfacecolor='k',markeredgecolor='k')
plt.plot(isocmd.isocmds[0]['Gaia_BP_EDR3']-isocmd.isocmds[0]['Gaia_RP_EDR3'],
         isocmd.isocmds[0]['Gaia_G_EDR3'],
        marker='.',markersize=1, markerfacecolor='k',markeredgecolor='k')
# B = isocmd.isocmds[0]['Bessell_B']
# V = isocmd.isocmds[0]['Bessell_V']
# plt.plot(B-V, V) 
plt.xlabel('Bp-Rp')
plt.ylabel(r'M$_G$')
plt.gca().invert_yaxis()
plt.title('log(age)=8.04, [Fe/H]=0.0, vrot/vcrit=0')
# plt.savefig('../trial_pleiades_iso')
plt.show()

# %%
bprp = np.asarray(isocmd1.isocmds[0]['Gaia_BP_EDR3']-isocmd1.isocmds[0]['Gaia_RP_EDR3'])
cmd_output = np.concatenate(([bprp],[isocmd1.isocmds[0]['Gaia_G_EDR3']]))

cmd_frame = pd.DataFrame(cmd_output.transpose(),columns=['Bp-Rp','M_G'])
cmd_frame
# Out:
#          Bp-Rp        M_G
# 0     3.242436  12.653936
# 1     3.237208  12.639269
# 2     3.213308  12.575703
# 3     3.187940  12.510616
# 4     3.159782  12.442286
# ...        ...        ...
# 1556 -0.515451   9.947474
# 1557 -0.513300   9.962188
# 1558 -0.511134   9.978391
# 1559 -0.509112  10.000200
# 1560 -0.507132  10.023991
#
# [1561 rows x 2 columns]

# %%
cmd_frame.to_csv('../pleiades_MISTisochrone_solar_4rot_gaiabands.csv',index=False)

# %%
isocmd1 = read_mist_models.ISOCMD('../MIST_iso_6369c12359ffa.iso.cmd')
# Out:
# Reading in: ../MIST_iso_6369c12359ffa.iso.cmd

# %%
plt.plot(isocmd1.isocmds[0]['Gaia_BP_EDR3']-isocmd1.isocmds[0]['Gaia_RP_EDR3'],
         isocmd1.isocmds[0]['Gaia_G_EDR3'],
        marker='.',markersize=1, markerfacecolor='k',markeredgecolor='k')
plt.xlabel('Bp-Rp')
plt.ylabel(r'M$_G$')
plt.gca().invert_yaxis()
plt.title('log(age)=8.04, [Fe/H]=0.0, vrot/vcrit=0.4')
# plt.savefig('../trial_pleiades_iso')
plt.show()

# %%
isocmd2 = read_mist_models.ISOCMD('../MIST_iso_6369c775165cf.iso.cmd')
# Out:
# Reading in: ../MIST_iso_6369c775165cf.iso.cmd

# %%
isocmd3 = read_mist_models.ISOCMD('../MIST_iso_6369c914898fc.iso.cmd')
# Out:
# Reading in: ../MIST_iso_6369c914898fc.iso.cmd

# %%
isocmd4 = read_mist_models.ISOCMD('../MIST_iso_6369c98ee3d5c.iso.cmd')
# Out:
# Reading in: ../MIST_iso_6369c98ee3d5c.iso.cmd

# %%
parsec = pd.read_csv('../output552737880804.dat',delimiter='\s+')
parsec
# Out:
#       Zini       MH  logAge      Mini   int_IMF   Mass   logL   logTe   logg  \
# 0    0.017  0.06676    8.04  0.090000  1.081690  0.090 -2.793  3.3952  4.718
# 1    0.017  0.06676    8.04  0.097136  1.146726  0.097 -2.734  3.4033  4.725
# 2    0.017  0.06676    8.04  0.100000  1.171106  0.100 -2.711  3.4066  4.727
# 3    0.017  0.06676    8.04  0.104142  1.204803  0.104 -2.681  3.4106  4.731
# 4    0.017  0.06676    8.04  0.115217  1.286953  0.115 -2.604  3.4213  4.740
# ..     ...      ...     ...       ...       ...    ...    ...     ...    ...
# 476  0.017  0.06676    8.04  5.133596  2.614736  2.515  4.431  3.4316 -0.914
# 477  0.017  0.06676    8.04  5.133612  2.614736  2.439  4.434  3.4288 -0.942
# 478  0.017  0.06676    8.04  5.133632  2.614736  2.348  4.434  3.4259 -0.970
# 479  0.017  0.06676    8.04  5.133656  2.614737  2.241  4.433  3.4227 -1.002
# 480  0.017  0.06676    8.04  5.133736  2.614737  0.902 -9.999  4.0000  0.981
#
#      label  ...       Y        Xc        Xn        Xo  Cexcess        Z  \
# 0        0  ...  0.2790  0.003057  0.000825  0.007479     -1.0  0.01700
# 1        0  ...  0.2790  0.003057  0.000825  0.007479     -1.0  0.01700
# 2        0  ...  0.2790  0.003057  0.000825  0.007479     -1.0  0.01700
# 3        0  ...  0.2790  0.003057  0.000825  0.007479     -1.0  0.01700
# 4        0  ...  0.2790  0.003057  0.000825  0.007479     -1.0  0.01700
# ..     ...  ...     ...       ...       ...       ...      ...      ...
# 476      8  ...  0.3717  0.001010  0.005109  0.005967     -1.0  0.01772
# 477      8  ...  0.3718  0.001019  0.005108  0.005967     -1.0  0.01773
# 478      8  ...  0.3718  0.001032  0.005108  0.005967     -1.0  0.01774
# 479      8  ...  0.3718  0.001047  0.005108  0.005967     -1.0  0.01776
# 480      9  ...  0.3719  0.001120  0.005107  0.005967     -1.0  0.01784
#
#      mbolmag    Gmag  G_BPmag  G_RPmag
# 0     11.752  13.812   16.563   12.336
# 1     11.605  13.665   16.417   12.188
# 2     11.547  13.607   16.360   12.130
# 3     11.473  13.533   16.287   12.056
# 4     11.280  13.284   15.968   11.819
# ..       ...     ...      ...      ...
# 476   -6.307   7.021   15.320    4.531
# 477   -6.315   8.377   17.225    5.809
# 478   -6.316   9.896   19.306    7.253
# 479   -6.313  11.730   21.800    9.009
# 480   29.767  29.977   29.967   29.984
#
# [481 rows x 31 columns]

# %%
plt.scatter(parsec['G_BPmag']-parsec['G_RPmag'],parsec['Gmag'],marker='.')
plt.gca().invert_yaxis()
plt.show()

# %%
temp = np.concatenate(([parsec['G_BPmag']-parsec['G_RPmag']],[parsec['Gmag']]))
# np.shape(temp.transpose())

parsec_frame = pd.DataFrame(temp.transpose(),columns=('Bp-Rp','M_G'))
parsec_frame
# Out:
#       Bp-Rp     M_G
# 0     4.227  13.812
# 1     4.229  13.665
# 2     4.230  13.607
# 3     4.231  13.533
# 4     4.149  13.284
# ..      ...     ...
# 476  10.789   7.021
# 477  11.416   8.377
# 478  12.053   9.896
# 479  12.791  11.730
# 480  -0.017  29.977
#
# [481 rows x 2 columns]

# %%
parsec_frame.to_csv('../pleiades_parsecisochrone_gaiabands.csv',index=False)

# %%
stellar_data = pd.read_csv('../pleiades-master-list-v02.csv')
stellar_data
# Out:
#      index   solution_id           source_id  random_index       ra  ra_error  \
# 0   4899.0  1.640000e+18   64679840952155264  8.747288e+08  54.6698    0.0337
# 1   5374.0  1.640000e+18   66715105696289024  9.213091e+08  56.8378    0.0460
# 2   4245.0  1.640000e+18   64053566003097984  1.743180e+09  57.4796    0.1184
# 3   5320.0  1.640000e+18   64956127609464320  1.368074e+09  56.4535    0.0393
# 4   3795.0  1.640000e+18   65776736943479808  4.630147e+08  59.5872    0.0374
# ..     ...           ...                 ...           ...      ...       ...
# 83     NaN           NaN  119006092005322112           NaN      NaN       NaN
# 84     NaN           NaN   62890175323180928           NaN      NaN       NaN
# 85     NaN           NaN  136347211441563136           NaN      NaN       NaN
# 86     NaN           NaN   70347033119553408           NaN      NaN       NaN
# 87     NaN           NaN  479937379577969792           NaN      NaN       NaN
#
#         dec  dec_error  parallax  parallax_error  ...  TIC_G  EDR3_e_plx  \
# 0   22.6594     0.0262    7.3736          0.0390  ...    NaN         NaN
# 1   24.1161     0.0332    7.1999          0.0598  ...    NaN         NaN
# 2   22.2440     0.0728    7.4144          0.1039  ...    NaN         NaN
# 3   23.1469     0.0261    7.4211          0.0420  ...    NaN         NaN
# 4   24.0809     0.0235    7.0196          0.0416  ...    NaN         NaN
# ..      ...        ...       ...             ...  ...    ...         ...
# 83      NaN        NaN    9.7448             NaN  ...    NaN      0.0417
# 84      NaN        NaN    9.6197             NaN  ...    NaN      0.0260
# 85      NaN        NaN    7.2322             NaN  ...    NaN      0.0380
# 86      NaN        NaN    6.5532             NaN  ...    NaN      0.0259
# 87      NaN        NaN    6.0836             NaN  ...    NaN      0.0161
#
#     EDR3_Mbol     EDR3_L  EDR3_BCv  vsini_zhou  vsini_torres  vsini_DR3  \
# 0         NaN        NaN       NaN  241.668855         230.0  196.58443
# 1         NaN        NaN       NaN  183.533821         171.0        NaN
# 2         NaN        NaN       NaN  132.593717          71.0        NaN
# 3         NaN        NaN       NaN  179.751738         173.0        NaN
# 4         NaN        NaN       NaN   66.535774          69.0        NaN
# ..        ...        ...       ...         ...           ...        ...
# 83   2.028320  12.152681 -0.025849         NaN           NaN  117.82155
# 84   2.483226   7.992993  0.017828         NaN           NaN  146.11395
# 85   2.464724   8.130373  0.016611         NaN           NaN  151.54709
# 86   2.645626   6.882555  0.014091         NaN         138.0  123.22632
# 87   2.769135   6.142512 -0.005682         NaN           NaN        NaN
#
#     source_vsini       vsini
# 0              1  241.668855
# 1              1  183.533821
# 2              1  132.593717
# 3              1  179.751738
# 4              1   66.535774
# ..           ...         ...
# 83             2  117.821550
# 84             2  146.113950
# 85             2  151.547090
# 86             1  138.000000
# 87             0         NaN
#
# [88 rows x 47 columns]

# %%
plt.figure(figsize=(10,6))
# plt.plot(isocmd.isocmds[0]['Gaia_BP_EDR3']-isocmd.isocmds[0]['Gaia_RP_EDR3'],
#          M_G,color='k',linewidth=1)
plt.plot(isocmd.isocmds[0]['Gaia_BP_EDR3']-isocmd.isocmds[0]['Gaia_RP_EDR3'],
         isocmd.isocmds[0]['Gaia_G_EDR3'],
         color='k',linewidth=1,label='v=0')
plt.plot(isocmd1.isocmds[0]['Gaia_BP_EDR3']-isocmd1.isocmds[0]['Gaia_RP_EDR3'],
         isocmd1.isocmds[0]['Gaia_G_EDR3'],
         color='tab:blue',linewidth=1,label='v=0.4')
# plt.plot(isocmd2.isocmds[0]['Gaia_BP_EDR3']-isocmd2.isocmds[0]['Gaia_RP_EDR3'],
#          isocmd2.isocmds[0]['Gaia_G_EDR3'],
#          color='tab:red',linewidth=1,label='v=0.0,Fe/H=0.05')
# plt.plot(isocmd3.isocmds[0]['Gaia_BP_EDR3']-isocmd3.isocmds[0]['Gaia_RP_EDR3'],
#          isocmd3.isocmds[0]['Gaia_G_EDR3'],
#          color='tab:green',linewidth=1,label='v=0.4,Fe/H=0.05')
# plt.plot(isocmd4.isocmds[0]['Gaia_BP_EDR3']-isocmd4.isocmds[0]['Gaia_RP_EDR3'],
#          isocmd4.isocmds[0]['Gaia_G_EDR3'],
#          color='tab:orange',linewidth=1,label='v=0.0,Fe/H=0.0,age=8.07')
plt.scatter(parsec['G_BPmag']-parsec['G_RPmag'],parsec['Gmag'],marker='^',color='k',label='PARSEC iso')
# plt.scatter(stellar_data['bp_rp']-0.045,stellar_data['M_G'],c=stellar_data['ruwe'])
plt.scatter(stellar_data['bp_rp']-0.045,stellar_data['M_G'],c=stellar_data['vsini'])
plt.gca().invert_yaxis()
plt.colorbar(label='RUWE')
# plt.clim(np.min(stellar_data['ruwe']),5)
plt.xlabel('Bp-Rp')
plt.ylabel('M_G')
plt.xlim(-0.1,.75)
plt.ylim(4,0)
plt.legend()
# plt.savefig('../solar_isos')
plt.show()

# %%
np.log10(120000000)
# Out:
# 8.079181246047625
