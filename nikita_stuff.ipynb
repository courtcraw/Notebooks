# %%
# Surface Abundance at RCB
# Profile 243 is RCB phase
# import mesa_reader as mr
import numpy as np
import matplotlib.pyplot as plt
#import pandas as pd
import re
import os
plt.rcParams['figure.figsize'] = (12,8)
plt.rcParams['font.size'] = 23
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 17
plt.rcParams['axes.labelsize'] = 25
plt.rcParams['axes.titlesize'] = 30
plt.rcParams['text.usetex'] = True
# Set the backend for higher resolution (retina for high-DPI displays)
# %config InlineBackend.figure_format = 'retina'
# import mesa_reader as mr
import numpy as np
import matplotlib.pyplot as plt
#import pandas as pd
import re
import os
import rcbtools as rcb
#pd.options.display.max_seq_items = 5
# M = 0.725M, q = 0.45, Z = 10% solar, coldest model made
# Set LaTeX font for the plot
plt.rcParams['text.usetex'] = True
# Set the backend for higher resolution (retina for high-DPI displays)
# %config InlineBackend.figure_format = 'retina'
# RCB Phase profiles in order

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
# main_folder = 'Sep18_TrendStudyBackup/Results/'
#RCB_profile1 = 'Sep18_TrendStudyBackup/Results/20230919_120305/LOGS/profile5.data'
#RCB_profile2 = 'Sep18_TrendStudyBackup/Results/20230919_120700/LOGS/profile6.data'
# import os
# plt.scatter(0, 0, color = 'purple', marker = '*')
# plt.scatter(0, 0, color = 'blue', marker = '*')
# plt.scatter(0, 0, color = 'green', marker = '*')
# plt.scatter(0, 0, color = 'yellow', marker = '*')
# plt.scatter(0, 0, color = 'red', marker = '*')
# RCB_profile_numbers = [5, 6, 5, 5, 4, 10, 8, 6, 10, 4, 16, 16, 10, 11, 6, 19, 14, 13, 16, 9, 31, 19, 23, 12, 10]
# main_folder = 'Sep18_TrendStudyBackup/Results/'
# Get a list of directories in the "Results" folder
# result_dirs = os.listdir(main_folder)
# Initialize a list to store the profile data file paths
profile_paths = []
# Iterate through the RCB_profile_numbers and construct paths
for i, profile_number in enumerate(RCB_profile_numbers, start=1):
    if i <= len(result_dirs):
        result_dir = result_dirs[i - 1]
        profile_path = f"{main_folder}{result_dir}/LOGS/profile{profile_number}.data"
        profile_paths.append(profile_path)
# Define the RCB_profile variables
for i, profile_path in enumerate(profile_paths, start=1):
    globals()[f'RCB_profile{i}'] = profile_path
# Print the defined RCB_profile variables
for i in range(1, 26):
    print(f"RCB_profile{i} = '{globals()[f'RCB_profile{i}']}'")
f, ax = rcb.rcbsurf(RCB_profile1,RCB_profile2,RCB_profile3, RCB_profile4, RCB_profile5, elements = ['Li', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg']
           ,legend = True, fig_handles = True, line = True, labels = [r'$0.525$', r'$0.550$', r'$0.625$', r'$0.650$', r'$0.675$'])
f.suptitle(r'$0.675M_{\odot}$ Abundances vs $q$')
f.subplots_adjust()
f.show()
f, ax = rcb.rcbsurf(RCB_profile6,RCB_profile7,RCB_profile8, RCB_profile9, RCB_profile10, elements = ['Li', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg']
           ,legend = True, fig_handles = True, line = True,labels = [r'$0.400$', r'$0.450$', r'$0.500$', r'$0.550$', r'$0.575$'])
f.suptitle(r'$0.7M_{\odot}$ Abundances vs $q$')
f.subplots_adjust()
f.show()
f, ax = rcb.rcbsurf(RCB_profile11,RCB_profile12,RCB_profile13, RCB_profile14, RCB_profile15, elements = ['Li', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg']
           ,legend = True, fig_handles = True, line = True,labels = [r'$0.350$', r'$0.400$', r'$0.450$', r'$0.500$', r'$0.550$'])
f.suptitle(r'$0.725M_{\odot}$ Abundances vs $q$')
f.subplots_adjust()
f.show()
f, ax = rcb.rcbsurf(RCB_profile16,RCB_profile17,RCB_profile18, RCB_profile19, RCB_profile20, elements = ['Li', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg']
           ,legend = True, fig_handles = True, line = True,labels = [r'$0.350$', r'$0.400$', r'$0.450$', r'$0.500$', r'$0.550$'])
f.suptitle(r'$0.75M_{\odot}$ Abundances vs $q$')
f.subplots_adjust()
f.show()
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
f, ax = rcb.rcbsurf(RCB_profile21, RCB_profile22, RCB_profile23, RCB_profile24, RCB_profile25, elements=['Li', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg'], legend=True, fig_handles=True, line=True, labels=[0.35, 0.40, 0.425, 0.55, 0.575])
f.suptitle(r'$0.775M_{\odot}$ Abundances vs $q$')
f.subplots_adjust()
plt.show()
print(rcb.__file__)

# %%
solar = {'Li' : 3.35,
         'C'  : 8.46,
         'N'  : 7.90,
         'O'  : 8.76,
         'F'  : 4.53,
         'Ne' : 7.95,
         'Na' : 6.37,
         'Mg' : 7.62,
         'Al' : 6.54,
         'Si' : 7.61,
         'S'  : 7.26,
         'Ca' : 6.41,
         'Sc' : 3.15,
         'Ti' : 5.00,
         'Ni' : 6.29,
         'Zn' : 4.70,
         'Y'  : 2.28,
         'Zr' : 2.67,
         'Ba' : 2.25,
         'La' : 1.25,
         'Fe' : 7.54
         }

# %%
def rcbsurf(pts, elements = [], savefig = None, ind_tau = None, labels = [],
            fig_handles = False, legend = False,\
               line = False):
    '''
    This function plots the surface abundances of a list of elements compared to observed RCB stars.
    As opposed to previous iterations, this function will take history datafiles or profiles for any
    list of elements as long as the elements exist in the list of observed RCB stars.
    
    Note: The history datafile can only be used if the surface values are printed to the history log.
    This means you should have a column called "rcb_<isotope>" in your history.data file.

    Parameters
    ----------
    *profiles : str
        Filepaths to profiles or history files.
    elements : list, optional
        List of elements to plot. Format should be uppercase followed by all lowercase.
        e.g. To plot Carbon, Nitrogen, Oxygen, and Lithium use ['C','N','O','Li'].
        
        If elements is left empty, default to ['Li','C','N','O','F','Ne','Na','Mg',
        'Al','Si','S','Ca','Sc','Ti','Ni','Zn','Y','Zr','Ba','La'].
        
        Note: Not all elements are included and will not work with this function. To add more
        elements, update the dictionaries "mus" and "solar" and the top of the __init__.py file.
        mus is the mean molecular mass of the element and solar is the normalizing amount of that
        element in the sun. Also, to add observed values, update the "observed_abund.csv" datafile
        included in this package.
    savefig : str, optional
        If a string is provided, save the plot under that filename. The default is None.
    ind_tau : int, optional
        If an integer is provided, use the first ind_tau rows as the photosphere (this assumes
        that the first row is the stars surface).
        The default is None.
    labels : list, optional
        List of strings for labels for a plot legend. If left empty, the default will be set
        to the profile filenames.
    observed_datafile : str, optional
        String for the filepath of the csv file for the observed abundances.
        The default is 'observed_abund.csv' and should be included in the rcbtools package.
    fig_handles : bool, optional
        If True, return the figure and subplot handles for user control. If you want to change
        the layout margins, first run the command with f, ax = rcbsurf(..., fig_handles = True).
        Then you can change the margins with f.subplots_adjust(). You will need this if using the legend.
    legend : bool, optional
        If True, use "labels" to make a legend on the figure.

    Returns
    -------
    Plots specified abundances.

    '''
    
    if not elements:
        elements = ['Li','C','N','O',\
                    'F','Ne','Na','Mg',\
                    'Al','Si','S','Ca',\
                    'Sc','Ti','Ni','Zn',\
                    'Y','Zr','Ba','La']
        
    file = pd.read_csv('./observed_abund.csv',delimiter=',')
    
    length = len(elements)
    
    row = int((length)**0.5)
    col = int(np.ceil(length/row))
    if row > col: row, col = col, row
    
    f, axarr = plt.subplots(row, col, figsize = [(col*3)+2,row*3],sharex = True,sharey=True)
    
    for i in range(row):
        for j in range(col):
            if col*i+j >= len(elements):
                break
            if elements[col*i+j] in file.columns:
                valid = np.where(file[elements[col*i+j]] == file[elements[col*i+j]])[0]
                axarr[i, j].scatter(file['Fe'][valid]-solar['Fe'], file[elements[col*i+j]][valid]-solar[elements[col*i+j]],\
                                    color=file['Color'][valid],marker='+')
                axarr[i, j].set_xlim([-2.7,-0.01])
                axarr[i, j].xaxis.set_tick_params()
                axarr[i, j].yaxis.set_tick_params()
                axarr[i, j].set_ylim([-2.4,3.6])
                axarr[i, j].text(-2.4, 2.5, elements[col*i+j], fontweight='bold')
                axarr[i, j].yaxis.offsetText.set_visible(False)
                if i == row - 1:
                    axarr[i, j].set_xlabel("[Fe]", fontweight='bold')
                if j == 0:
                    axarr[i, j].set_ylabel("[X]", fontweight='bold')
                    
    f.subplots_adjust(left = 0.05, right = 0.82, top = 0.9, bottom = 0.08,\
                    wspace=0, hspace=0)
    
    autolabel = labels.copy()
    
#     for index,profile in enumerate(profiles):
#         p = profile2dict(profile,global_headers = True)
#         if 'zone' in p.keys():
#             abunds = makeabund(profile)
#             dm = p['dm']
#             if ind_tau:
#                 ind = ind_tau
#             else:
#                 tau = p['tau']
#                 ind = np.argmin(abs(tau-1.0))
#             for ele in abunds:
#                 abunds[ele] = sum(dm[0:ind]*abunds[ele][0:ind])/sum(dm[0:ind])
#             RCB_age = p['star_age']
#             RCB_model = p['model_number']
#         else:
#             abunds = historyabund(profile)
#             ind = np.argmin(p['log_Teff'])
#             for ele in abunds:
#                 abunds[ele] = abunds[ele][ind]
#             RCB_age = p['star_age'][ind]
#             RCB_model = p['model_number'][ind]
        
#         keys = list(abunds.keys())
        
#         values = {}
#         if 'Fe' in keys:
#             values['Fe'] = np.log10(abunds['Fe'])-np.log10(mus['Fe'])+12.15
#         else:
#             values['Fe'] = solar['Fe']
#         print('----------------------------------------------------------------')
#         print('PARAMETERS OF INTEREST')
#         print('----------------------------------------------------------------')
#         print('C12/C13 ', (abunds['c12']/abunds['c13'])*(13/12))
#         print('O16/O18 ', round((abunds['o16']/abunds['o18'])*(18/16),2))
#         print('C/O     ', round((abunds['C']/abunds['O'])*(mus['O']/mus['C']),2))
#         print('RCB Age ', round(float(RCB_age)), 'years')
#         print('Model   ', int(RCB_model))
        
#         print('----------------------------------------------------------------')	
#         print('SURFACE ABUNDANCES FOR SELECTED SPECIES (Solar Unit Abundances)')
#         print('----------------------------------------------------------------')
#         for element in elements:
#             if element in keys:
#                 values[element] = np.log10(abunds[element])-np.log10(mus[element])+12.15
#             else:
#                 values[element] = -99
#             print(element,round(values[element]-solar[element],3))
        
#         if not labels: autolabel.append(profile)
        
    for i in range(row):
        for j in range(col):
            if line:
                axarr[i, j].plot([-5,5],[-5,5],'k--')
            if col*i+j >= len(elements):
                break
            #### courtney addition to add cm = to both of these ###
            # this tells f.colorbar which axis to use the colorbar on
            if i == j == 0:
                cm = axarr[i, j].scatter(pts[:,0],pts[:,1],label=autolabel,marker='*')
            else:
                cm = axarr[i, j].scatter(pts[:,0],pts[:,1],marker='*')
    
    if legend: f.legend(loc='center right')
    f.align_ylabels(axarr[:,0])
    ### courtney addition ###
#     f.colorbar(cm, ax=axarr[:], label='insert label')
    ### courtney addition ###
    f.show()
    if savefig: f.savefig(savefig)
    if fig_handles: return f, axarr

# %%
import matplotlib as mpl

# %%
rainbow_colors = ['#FF0000', '#FF4000', '#FF7F00', '#FFBF00', '#FFFF00', '#00FF00', '#0080FF', '#0000FF']
teal_colors = ['#1E90FF', '#1C86EE', '#1874CD', '#104E8B', '#0D3D5D']
teal_cmap = mpl.colors.ListedColormap(teal_colors)

# %%
plot_examples([teal_cmap])

# %%
def plot_examples(colormaps):
    """
    Helper function to plot data with associated colormap.
    """
    np.random.seed(19680801)
    data = np.random.randn(30, 30)
    n = len(colormaps)
    fig, axs = plt.subplots(1, n, figsize=(n * 2 + 2, 3),
                            layout='constrained', squeeze=False)
    for [ax, cmap] in zip(axs.flat, colormaps):
        psm = ax.pcolormesh(data, cmap=cmap, rasterized=True, vmin=-4, vmax=4)
        fig.colorbar(psm, ax=ax)
    plt.show()

# %%
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

# %%
### in __init__.py you will need to change the figure initialization to this ####
## f, axarr = plt.subplots(row, col, figsize = [(col*3)+2,row*3],sharex = True,sharey=True) ##
## to add in the extra horizontal space for the colorbar

import matplotlib as mpl
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

f, ax = rcbsurf(np.asarray([[0,0],[-1,-1],[-1,0]]), elements = ['Li', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg']
           ,legend = False, fig_handles = True, line = True, labels = [r'$0.525$', r'$0.550$'])
f.suptitle(r'$0.675M_{\odot}$ Abundances vs $q$')
# f.subplots_adjust()

rainbow_colors = ['#FF0000', '#FF4000', '#FF7F00', '#FFBF00', '#FFFF00', '#00FF00', '#0080FF', '#0000FF']
teal_colors = ['#1E90FF', '#1C86EE', '#1874CD', '#104E8B', '#0D3D5D']
teal_cmap = mpl.colors.ListedColormap(teal_colors)
cmappable = ScalarMappable(Normalize(0,1),cmap=teal_cmap)
cb = f.colorbar(cmappable, ax=ax[:], label='insert label',pad=0.01,cmap=teal_cmap)
cb.set_ticks([0.1,0.3,0.5,0.7,0.9],labels=['0.1','0.3','0.5','0.7','0.9'])


f.show()
# Out:
# /var/folders/5_/9nz8zb3j1nd7ngnmb4btgpjh0000gq/T/ipykernel_3152/299909307.py:162: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()
# /var/folders/5_/9nz8zb3j1nd7ngnmb4btgpjh0000gq/T/ipykernel_3152/2084638801.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()
